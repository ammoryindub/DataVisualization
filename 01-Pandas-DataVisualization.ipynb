# %% [markdown]
# # DataVisualization using Pandas

# %% [markdown]
# We can modify the sample data or add our own dataset to the DataFrame to visualize our data. Additionally, you can customize the plot titles, labels, colors, and other properties as per your requirements

# %%
# Import libraries

import numpy as np 

import pandas as pd

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import seaborn as sns

# %%
# we call our dataset

df = pd.read_csv('dataset.csv')

# %%
df
# Out:
#             a         b         c         d
# 0    0.336272  0.325011  0.001020  0.401402
# 1    0.980265  0.831835  0.772288  0.076485
# 2    0.480387  0.686839  0.000575  0.746758
# 3    0.502106  0.305142  0.768608  0.654685
# 4    0.856602  0.171448  0.157971  0.321231
# ..        ...       ...       ...       ...
# 495  0.528705  0.226122  0.055835  0.131962
# 496  0.324730  0.215201  0.935302  0.794115
# 497  0.118036  0.264574  0.629206  0.824062
# 498  0.227021  0.660209  0.851353  0.478676
# 499  0.466157  0.753000  0.115391  0.279712
#
# [500 rows x 4 columns]

# %% [markdown]
# #### let's start with performing a scatter plot using DataFrames, to visualize "column a" against "column b"

# %%
# calling plot on dataframe

df.plot.scatter(x='a', y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
# using scatter plot arguments

df.plot.scatter(x='a', y='b',figsize=(10,3),s=25, c='green')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %% [markdown]
# #### using a histogram plot to visualize column c

# %%
# data index ['c'], calling histogram plot

df['c'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# using some arguments changing bins number

df['c'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### try using plot style, and then calling a plot

# %%
# using style.use method 

plt.style.use('ggplot')

# %%
# after applying the style method we can see the plot for a similar column has changed.

df['c'].plot.hist(bins=50, alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### creating a boxplot comparing columns (a, b, c)

# %%
# call box plot

df[['a','b','c']].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### creating KDE plot for column d

# %%
df['d'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# using arguments on KDE plot

df['d'].plot.kde(lw='3', ls='--')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# #### create an area plot of all columns, only the rows up to 50

# %% [markdown]
# first, we will use slicing to choose the rows we will work with using iloc method

# %%
df.loc[0:50]

# or df.iloc[0:51]
# Out:
#            a         b         c         d
# 0   0.336272  0.325011  0.001020  0.401402
# 1   0.980265  0.831835  0.772288  0.076485
# 2   0.480387  0.686839  0.000575  0.746758
# 3   0.502106  0.305142  0.768608  0.654685
# 4   0.856602  0.171448  0.157971  0.321231
# 5   0.705973  0.632689  0.504017  0.313622
# 6   0.166724  0.269734  0.608569  0.874427
# 7   0.054041  0.966440  0.065596  0.109448
# 8   0.757839  0.523885  0.527210  0.226936
# 9   0.425383  0.213701  0.049020  0.287598
# 10  0.176837  0.166534  0.779374  0.936486
# 11  0.221546  0.660821  0.811782  0.392565
# 12  0.001350  0.450186  0.076469  0.753368
# 13  0.537323  0.623779  0.071851  0.751200
# 14  0.032284  0.050182  0.897562  0.614129
# 15  0.488804  0.091374  0.203803  0.179708
# 16  0.821116  0.191407  0.756962  0.592383
# 17  0.202699  0.103978  0.342236  0.787626
# 18  0.185218  0.751554  0.612737  0.088429
# 19  0.842810  0.842357  0.206589  0.389940
# 20  0.844033  0.449981  0.132198  0.103938
# ...

# %%
# calling areaplot

df.loc[0:50].plot.area()
# Out:
# <AxesSubplot:>

# %%
# use areaplot arguments 

df.loc[0:50].plot.area(alpha=0.6)
# Out:
# <AxesSubplot:>

# %%
# more arguments, putting the legend outside

fig = plt.figure()
df.loc[0:50].plot.area(alpha=0.6)
plt.legend(loc='center left', bbox_to_anchor=(1.0,0.5))

# %% [markdown]
# ### - - - - The End - - - -
